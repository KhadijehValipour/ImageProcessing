# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('download.jpg')
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (124, 406, 3)

# %%
# display output 1

cv2.imshow("",img[:,:,0])

cv2.waitKey(0)
# Out:
# -1

# %%
#display output 2

plt.imshow(img[:,:,0])

plt.show()

# %%
#display output 3

cv2.imshow("", img[:,:,0])

cv2.waitKey(0)
# Out:
# -1

# %%
plt.imshow(img[:,:,1])

plt.show()

# %%
plt.imshow(img[:,:,2])

plt.show()

# %%
plt.imshow(img)
